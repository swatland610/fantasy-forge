# %%
import nflreadpy as nfl

# %%
data = nfl.load_pbp(seasons=True)

# %%
nfl.load_draft_picks(seasons=[2025])
# Out:
# shape: (257, 36)
# ┌────────┬───────┬──────┬──────┬───┬─────────┬──────────────────┬──────────┬───────────┐
# │ season ┆ round ┆ pick ┆ team ┆ … ┆ rec_tds ┆ def_solo_tackles ┆ def_ints ┆ def_sacks │
# │ ---    ┆ ---   ┆ ---  ┆ ---  ┆   ┆ ---     ┆ ---              ┆ ---      ┆ ---       │
# │ i32    ┆ i32   ┆ i32  ┆ str  ┆   ┆ i32     ┆ i32              ┆ i32      ┆ f64       │
# ╞════════╪═══════╪══════╪══════╪═══╪═════════╪══════════════════╪══════════╪═══════════╡
# │ 2025   ┆ 1     ┆ 1    ┆ TEN  ┆ … ┆ 0       ┆ null             ┆ null     ┆ null      │
# │ 2025   ┆ 1     ┆ 2    ┆ JAX  ┆ … ┆ 1       ┆ 11               ┆ null     ┆ null      │
# │ 2025   ┆ 1     ┆ 3    ┆ NYG  ┆ … ┆ 0       ┆ 25               ┆ null     ┆ 4.0       │
# │ 2025   ┆ 1     ┆ 4    ┆ NWE  ┆ … ┆ 0       ┆ null             ┆ null     ┆ null      │
# │ 2025   ┆ 1     ┆ 5    ┆ CLE  ┆ … ┆ 0       ┆ 27               ┆ null     ┆ 0.5       │
# ...
